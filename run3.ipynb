# %% [markdown]
# <a href="https://colab.research.google.com/github/maysarahammouda/GradComp/blob/master/run3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# 4/2AEUqni9TkDl6_cSosMaIz_3mNuQLZnOridSXigLR3vb4jVSEQTyFoE
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# ---------------------------------------------------------------------------
# TIMEOUT                                   Traceback (most recent call last)
# <ipython-input-1-f692680317bf> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/gdrive')
#       3 # 4/2AEUqni9TkDl6_cSosMaIz_3mNuQLZnOridSXigLR3vb4jVSEQTyFoE
#
# ...

# %%
# %cd gdrive/My Drive/GradientCompression    
# %cd GradComp
# !pip install wandb
# !wandb on
# 6a2919c7326656bd197373c2e61d41146ae40bbf
# Out:
# /content/gdrive/My Drive/GradientCompression
# /content/gdrive/My Drive/GradientCompression/GradComp
# ...
# W&B enabled, running your script from this directory will now sync to the cloud.

# %%
# !nvidia-smi
# Out:
# Mon Jul 20 07:18:43 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.51.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
! python main.py --data ../datasets/ptb --num_layers 2 --init_lr 20.0 --lr_decay 0.0 --epochs 70 --eval_batch_size 10 --test_batch_size 10 --bptt 43 --dropout 0.7003 --seed 1111 --log_interval 1 --clip 0.25 --use_gpu true --emb_size 700 --num_hid 700 --num_workers 1 --batch_size 128 --compressor topk --compress_ratio 0.001 --memory residual --exp_name TopK_0.001_1_worker --project_name multi_workers_arch_1
# Out:
# wandb: Tracking run with wandb version 0.9.3
# wandb: Run data is saved locally in wandb/run-20200719_203008-3s9najgh
# wandb: Syncing run TopK_0.001_1_worker
# wandb: ⭐️ View project at https://app.wandb.ai/maysara/multi_workers_arch_1
# wandb: 🚀 View run at https://app.wandb.ai/maysara/multi_workers_arch_1/runs/3s9najgh
# wandb: Run `wandb off` to turn off syncing.
#
# You have a CUDA device and run on gpu.
# ...
# |                    Training                    |
# ...
# | epoch   1 |   127/  169 batches | lr 20.0000 | ms/batch  3.07 | loss  7.13 | ppl  1248.17
# | epoch   1 |   167/  169 batches | lr 20.0000 | ms/batch  3.05 | loss  7.00 | ppl  1098.38
# --------------------------------------------------------------------------------------------
# | end of epoch   1 | time: 68.24s | valid loss  6.55 | valid ppl   696.37
# --------------------------------------------------------------------------------------------
# ...

# %%
! python main.py --data ../datasets/ptb --num_layers 2 --init_lr 20.0 --lr_decay 0.0 --epochs 70 --eval_batch_size 10 --test_batch_size 10 --bptt 43 --dropout 0.7003 --seed 1111 --log_interval 1 --clip 0.25 --use_gpu true --emb_size 700 --num_hid 700 --num_workers 2 --batch_size 64 --compressor topk --compress_ratio 0.001 --memory residual --exp_name TopK_0.001_2_worker --project_name multi_workers_arch_1
# Out:
# wandb: Tracking run with wandb version 0.9.3
# wandb: Run data is saved locally in wandb/run-20200719_215414-mzoxjbzm
# wandb: Syncing run TopK_0.001_2_worker
# wandb: ⭐️ View project at https://app.wandb.ai/maysara/multi_workers_arch_1
# wandb: 🚀 View run at https://app.wandb.ai/maysara/multi_workers_arch_1/runs/mzoxjbzm
# wandb: Run `wandb off` to turn off syncing.
#
# You have a CUDA device and run on gpu.
# ...
# |                    Training                    |
# ...
# | epoch   1 |   127/  338 batches | lr 20.0000 | ms/batch  4.93 | loss  7.46 | ppl  1729.07
# | epoch   1 |   255/  338 batches | lr 20.0000 | ms/batch  5.18 | loss  7.17 | ppl  1296.20
# --------------------------------------------------------------------------------------------
# | end of epoch   1 | time: 115.00s | valid loss  6.33 | valid ppl   560.39
# --------------------------------------------------------------------------------------------
# ...

# %%
! python main.py --data ../datasets/ptb --num_layers 2 --init_lr 20.0 --lr_decay 0.0 --epochs 70 --eval_batch_size 10 --test_batch_size 10 --bptt 43 --dropout 0.7003 --seed 1111 --log_interval 1 --clip 0.25 --use_gpu true --emb_size 700 --num_hid 700 --num_workers 4 --batch_size 32 --compressor topk --compress_ratio 0.001 --memory residual --exp_name TopK_0.001_4_workers --project_name multi_workers_arch_1
# Out:
# wandb: Tracking run with wandb version 0.9.3
# wandb: Run data is saved locally in wandb/run-20200720_001801-38f69al2
# wandb: Syncing run TopK_0.001_4_workers
# wandb: ⭐️ View project at https://app.wandb.ai/maysara/multi_workers_arch_1
# wandb: 🚀 View run at https://app.wandb.ai/maysara/multi_workers_arch_1/runs/38f69al2
# wandb: Run `wandb off` to turn off syncing.
#
# You have a CUDA device and run on gpu.
# ...
# |                    Training                    |
# ...
# | epoch   1 |   127/  676 batches | lr 20.0000 | ms/batch  9.13 | loss  8.08 | ppl  3218.87
# | epoch   1 |   255/  676 batches | lr 20.0000 | ms/batch  9.38 | loss  7.83 | ppl  2506.95
# | epoch   1 |   383/  676 batches | lr 20.0000 | ms/batch  9.56 | loss  7.76 | ppl  2335.88
# | epoch   1 |   511/  676 batches | lr 20.0000 | ms/batch  9.79 | loss  7.52 | ppl  1845.35
# | epoch   1 |   639/  676 batches | lr 20.0000 | ms/batch  9.87 | loss  7.38 | ppl  1609.42
# ...

# %%
! python main.py --data ../datasets/ptb --num_layers 2 --init_lr 20.0 --lr_decay 0.0 --epochs 70 --eval_batch_size 10 --test_batch_size 10 --bptt 43 --dropout 0.7003 --seed 1111 --log_interval 1 --clip 0.25 --use_gpu true --emb_size 700 --num_hid 700 --num_workers 8 --batch_size 16 --compressor topk --compress_ratio 0.001 --memory residual --exp_name TopK_0.001_8_workers --project_name multi_workers_arch_1
# Out:
# wandb: Tracking run with wandb version 0.9.3
# wandb: Run data is saved locally in wandb/run-20200720_064912-imfvugsa
# wandb: Syncing run TopK_0.001_8_workers
# wandb: ⭐️ View project at https://app.wandb.ai/maysara/multi_workers_arch_1
# wandb: 🚀 View run at https://app.wandb.ai/maysara/multi_workers_arch_1/runs/imfvugsa
# wandb: Run `wandb off` to turn off syncing.
#
# You have a CUDA device and run on gpu.
# ...
# |                    Training                    |
# ...
# | epoch   1 |   127/ 1352 batches | lr 20.0000 | ms/batch 17.46 | loss  8.95 | ppl  7728.35
# | epoch   1 |   255/ 1352 batches | lr 20.0000 | ms/batch 18.29 | loss  9.54 | ppl 13884.23
# | epoch   1 |   383/ 1352 batches | lr 20.0000 | ms/batch 17.95 | loss  9.59 | ppl 14636.45
# | epoch   1 |   511/ 1352 batches | lr 20.0000 | ms/batch 18.53 | loss  9.26 | ppl 10539.49
# | epoch   1 |   639/ 1352 batches | lr 20.0000 | ms/batch 19.31 | loss  8.83 | ppl  6833.21
# ...

# %%
! python main.py --data ../datasets/ptb --num_layers 2 --init_lr 20.0 --lr_decay 0.0 --epochs 70 --eval_batch_size 10 --test_batch_size 10 --bptt 43 --dropout 0.7003 --seed 1111 --log_interval 1 --clip 0.25 --use_gpu true --emb_size 700 --num_hid 700 --num_workers 16 --batch_size 8 --compressor topk --compress_ratio 0.001 --memory residual --exp_name TopK_0.001_16_workers --project_name multi_workers_arch_1

# %%
! wandb agent maysara/random_search_4/2f0f0ulf
# Out:
# wandb: Starting wandb agent 🕵️
# 2020-07-20 07:19:06,398 - wandb.wandb_agent - INFO - Running runs: []
# 2020-07-20 07:19:06,591 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-07-20 07:19:06,592 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	batch_size: 128
# 	bptt: 47
# 	compressor: none
# 	dropout: 0.7849512920570277
# 	emb_size: 375
# 	epochs: 70
# 	init_lr: 26
# 	memory: none
# 	num_layers: 2
# 2020-07-20 07:19:06,673 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python main.py --batch_size=128 --bptt=47 --compressor=none --dropout=0.7849512920570277 --emb_size=375 --epochs=70 --init_lr=26 --memory=none --num_layers=2
# wandb: Tracking run with wandb version 0.9.3
# wandb: Run data is saved locally in wandb/run-20200720_071906-he1s1leq
# wandb: Syncing run leafy-sweep-54
# wandb: ⭐️ View project at https://app.wandb.ai/maysara/random_search_4
# wandb: 🧹 View sweep at https://app.wandb.ai/maysara/random_search_4/sweeps/2f0f0ulf
# ...
